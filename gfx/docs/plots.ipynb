# %%
import os
import ska

# %% [markdown]
# # Transmission curve

# %%
gaia = ska.Filter('GAIA/GAIA3.Grp')

# %% [markdown]
# ## Light version

# %%
f, a  = gaia.plot_transmission(figure=os.path.join("..", "..","docs","gfx","ska_filter_light.png"))

# %% [markdown]
# ## Dark version

# %%
f, a  = gaia.plot_transmission(figure=os.path.join("..", "..","docs","gfx","ska_filter_dark.png"), black=True)
